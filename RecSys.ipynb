# %%
import pandas as pd 
import numpy as np

# %%
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')

# %%
x = ratings

# %%
ratings.drop(['timestamp'],axis=1, inplace=True)

# %% [markdown]
# ratings.head(5)

# %%
print(ratings.head())
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.tail()
# Out:
#       movieId                                      title  \
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                genres
# 9737  Action|Animation|Comedy|Fantasy
# 9738         Animation|Comedy|Fantasy
# 9739                            Drama
# 9740                 Action|Animation
# 9741                           Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
def replace_name(x):
    return movies[movies['movieId'] == x ].title.values[0]
ratings.movieId = ratings.movieId.map(replace_name)

# %%
ratings.head()
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.tail()
# Out:
#         userId                         movieId  rating
# 100831     610                    Split (2017)     4.0
# 100832     610   John Wick: Chapter Two (2017)     5.0
# 100833     610                  Get Out (2017)     5.0
# 100834     610                    Logan (2017)     5.0
# 100835     610  The Fate of the Furious (2017)     3.0

# %%
ratings_matrix = ratings.pivot_table(index=['userId'], columns=['movieId'], values='rating')

# %%
ratings_matrix
# Out:
# movieId  '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
# 5               NaN                                      NaN
# 6               NaN                                      NaN
# 7               NaN                                      NaN
# 8               NaN                                      NaN
# 9               NaN                                      NaN
# 10              NaN                                      NaN
# 11              NaN                                      NaN
# 12              NaN                                      NaN
# 13              NaN                                      NaN
# 14              NaN                                      NaN
# ...

# %%
ratings.plot.bar(y='userId',x='movieId')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-087665dd7abf> in <module>
# ----> 1 ratings.plot.bar(y='userId',x='movieId')
#
# NameError: name 'ratings' is not defined

# %%
def pearson_r(x1, y1):
    """Take two pd series objects and returns a pearson correlation"""
    x1_c = x1 - x1.mean()
    y2_c = y1 - y1.mean()
    return np.sum(x1_c * y2_c)/ np.sqrt(np.sum(x1_c ** 2) * np.sum(y2_c ** 2))

# %%
pearson_r(ratings_matrix['Planet Earth II (2016)'], ratings_matrix['xXx (2002)'] )
# Out:
# 0.06927010190850649

# %%
def getTopRecs(movie_name, M, num):
    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson_r(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title,cor))
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %%
recommendations = getTopRecs('Avengers: Age of Ultron (2015)', ratings_matrix, 10)
recommendations[:10]
# Out:
# C:\Users\TomideAina\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   """
# [('Iron Man 3 (2013)', 0.6281758572015976),
#  ('Tomb Raider (2018)', 0.5675904398983596),
#  ('Captain America: The First Avenger (2011)', 0.5472048105219247),
#  ('Thor (2011)', 0.5425554586372479),
#  ('War for the Planet of the Apes (2017)', 0.5419081496841721),
#  ('Pirates of the Caribbean: On Stranger Tides (2011)', 0.5404307901634368),
#  ('Star Trek Into Darkness (2013)', 0.5080100834582241),
#  ('It (2017)', 0.4947924883390154),
#  ('Thor: The Dark World (2013)', 0.49317176939330987),
#  ('Amazing Spider-Man, The (2012)', 0.4738497871820777)]

# %%
"""Generating Anti Recommendations """
anti_recommendations = getTopRecs('Avengers: Age of Ultron (2015)', ratings_matrix, 10)
anti_recommendations[-10:]
# Out:
# C:\Users\TomideAina\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   """
# [('Partly Cloudy (2009)', -0.23526155774686186),
#  ('Call Me by Your Name (2017)', -0.2460143056922308),
#  ('Blind Swordsman: Zatoichi, The (Zatôichi) (2003)', -0.24897119885131697),
#  ('Cake (2014)', -0.2593218476574587),
#  ('Machete Kills (Machete 2) (2013)', -0.2593218476574587),
#  ('Saw (2003)', -0.2593218476574587),
#  ("Blue Is the Warmest Color (La vie d'Adèle) (2013)", -0.32415230957182334),
#  ('Dragon Ball Z the Movie: The Tree of Might (Doragon bôru Z 3: Chikyû marugoto chô kessen) (1990)',
#   -0.32415230957182334),
#  ("Dragon Ball: Sleeping Princess in Devil's Castle (Doragon bôru: Majinjô no nemuri hime) (1987)",
#   -0.32415230957182334),
#  ('Silence (2016)', -0.32415230957182334)]

# %%
   def getPopularityRanks():
        import csv 
        from collections import defaultdict
        ratings = defaultdict(int)
        rankings = defaultdict(int)
        with open('ratings.csv', newline='') as csvfile:
            ratingReader = csv.reader(csvfile)
            next(ratingReader)
            for row in ratingReader:
                movieID = int(row[1])
                ratings[movieID] += 1
        rank = 1
        for movieID, ratingCount in sorted(ratings.items(), key=lambda x: x[1], reverse=True):
            rankings[movieID] = rank
            rank += 1
        return rankings

# %%
ratings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0f451246ac4e> in <module>
# ----> 1 ratings
#
# NameError: name 'ratings' is not defined

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(ratings['userId'],ratings['movieId'],test_size=.3,random_state=34567)
